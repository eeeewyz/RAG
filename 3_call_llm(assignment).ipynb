# %% [markdown]
# <a href="https://colab.research.google.com/github/eeeewyz/RAG/blob/main/3_call_llm(assignment).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
torch.cuda.is_available()
# Out:
# False

# %%
device=torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %%
model=Model().to(device)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_10057/3353123356.py in <cell line: 0>()
# ----> 1 model=Model().to(device)
#
# NameError: name 'Model' is not defined

# %%
for inputs,targets in dataloader:
    inputs=inputs.to(device)
    targets=targets.to(device)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_10057/1717131967.py in <cell line: 0>()
# ----> 1 for inputs,targets in dataloader:
#       2     inputs=inputs.to(device)
#       3     targets=targets.to(device)
#
# NameError: name 'dataloader' is not defined
